# %% [markdown]
# ## Bug report classification

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from time import time
import matplotlib.pyplot as plt
import sklearn.preprocessing
import os,re

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/ping-dev04/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ### Build data

# %%
data = pd.read_csv('idata.csv')

# %%
data.head()
# Out:
#       Bug ID              Product        Component  \
# 0  1436291.0  Firefox for Android  Activity Stream
# 1  1436379.0  Firefox for Android  Activity Stream
# 2  1254660.0  Firefox for Android  Activity Stream
# 3  1273667.0  Firefox for Android  Activity Stream
# 4  1299685.0  Firefox for Android  Activity Stream
#
#                                              Summary
# 0  Context menu animation broken when "Delete fro...
# 1  Links do not work when Pocket stories are upda...
# 2  Don't list both http and https versions of a U...
# 3  Simplify long-press context menu for top sites...
# 4  Consider replacing ActivityStream topsites' Vi...

# %%
train = pd.DataFrame()
train['bugID'] = data['Bug ID']
train['text'] = data['Summary']

# %%
train.head()
# Out:
#        bugID                                               text
# 0  1436291.0  Context menu animation broken when "Delete fro...
# 1  1436379.0  Links do not work when Pocket stories are upda...
# 2  1254660.0  Don't list both http and https versions of a U...
# 3  1273667.0  Simplify long-press context menu for top sites...
# 4  1299685.0  Consider replacing ActivityStream topsites' Vi...

# %% [markdown]
# --------------

# %% [markdown]
# ### TFIDF Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="word",
                                   tokenizer=nltk.word_tokenize,
                                   preprocessor=None,
                                   stop_words='english',
                                   max_features=None)
sparce_tfidf = tfidf_vectorizer.fit_transform(train['text'])

# %%
from sklearn.decomposition import TruncatedSVD

# %%
svd = TruncatedSVD(n_components=100, n_iter=25, random_state=12)
t_tfidf = svd.fit_transform(sparce_tfidf)

# %% [markdown]
# -----------------

# %% [markdown]
# ### GMM

# %%
from sklearn.mixture import GaussianMixture as GMM
from sklearn.metrics import silhouette_score

# %%
from IPython.display import display

# %%
# method to find the best n_components
def score_cluster(data, num_components):
    clusterer = GMM(n_components=num_components)
    clusterer.fit(data)
    preds = clusterer.predict(data)
    score = silhouette_score(data, preds)
    return score

# %%
print ("Silhouette Score for different sizes")
silhouette_scores_matrix = pd.DataFrame(index=['Score'])
# Out:
# Silhouette Score for different sizes

# %%
for size in range(2,11):
    silhouette_scores_matrix[size] = \
    pd.Series(score_cluster(t_tfidf, size),\
    index = silhouette_scores_matrix.index)

# %%
display(silhouette_scores_matrix)

best_n_components = 4

# Apply the selected clustering algorithm to the reduced data 
clusterer = GMM(n_components=best_n_components)
clusterer.fit(t_tfidf)

# Predict the cluster for each data point
preds = clusterer.predict(t_tfidf)

# Find the cluster centers
centers = clusterer.means_

# Predict the cluster for each transformed sample data point
sample_preds = clusterer.predict(t_tfidf[0:10])

# Calculate the mean silhouette coefficient for the number of clusters chosen
score = silhouette_score(t_tfidf, preds)

print("Best Score: {}, n_components={}".format(score, best_n_components))
# Out:
#              2        3         4         5         6         7         8   \
# Score  0.005143  0.02447 -0.021008 -0.045891 -0.070014 -0.139402 -0.059499
#
#              9         10
# Score -0.065885 -0.050004
# Best Score: -0.024534382312752127, n_components=4

# %%
silhouette_scores_matrix.plot(kind = "barh",figsize=(16,4))

# %% [markdown]
# ### Result

# %%
preds
# Out:
# array([3, 1, 3, ..., 0, 0, 0])

# %% [markdown]
# ### Severity sclae is : 0,1,2,4

# %%
resultdf = train.copy(deep =True)

# %%
resultdf['label'] = preds

# %%
resultdf.head(100)
# Out:
#         bugID                                               text  label
# 0   1436291.0  Context menu animation broken when "Delete fro...      3
# 1   1436379.0  Links do not work when Pocket stories are upda...      1
# 2   1254660.0  Don't list both http and https versions of a U...      3
# 3   1273667.0  Simplify long-press context menu for top sites...      3
# 4   1299685.0  Consider replacing ActivityStream topsites' Vi...      1
# 5   1315197.0   Activity Stream topsites: fix default announc...      1
# 6   1319485.0  Add domains table, with domain_id FK in histor...      0
# 7   1320803.0  Ability to store/retrieve custom name for a To...      3
# 8   1320806.0  Allow removing Top Sites items without removin...      3
# 9   1322501.0  Asynchronously obtain, send, and store image d...      3
# 10  1322564.0            Consider loading icons from the network      1
# 11  1324452.0  Context menu is misplaced and wrongly rendered...      3
# 12  1333545.0  Box/Border around items in NavigationView on A...      3
# 13  1335817.0   Highlights algorithm: Add domain visit frequency      0
# 14  1335819.0          Highlights algorithm: Use main image size      3
# 15  1335824.0  Highlights algorithm: Consider lowering score ...      1
# 16  1338561.0  An incomplete preview context menu is displaye...      1
# 17  1340541.0  Add toast when user chooses to Copy Address fr...      3
# 18  1350886.0      Remove MOZ_ANDROID_ACTIVITY_STREAM build flag      3
# 19  1352342.0             Screen is hard to use on large tablets      3
# 20  1377292.0                                Unify context menus      3
# 21  1386725.0  Remove old top sites code once the new Activit...      3
# 22  1388187.0                Highlights query is still very slow      0
# 23  1388392.0                Top Sites: Show next page partially      3
# 24  1388415.0   Investigate how big highlight preview images are      3
# 25  1388558.0  Default top-sites background is the same as th...      1
# 26  1389200.0  Add "Save to Pocket" to context menu options f...      3
# 27  1389259.0  Use screenshots for pages in Top Sites for low...      3
# 28  1390257.0  Default "letter" favicons font size seems too ...      3
# 29  1390970.0   Add Pocket entry point if Pocket isn't installed      0
# ..        ...                                                ...    ...
# 70  1038960.0  Unable to pin top site: foreign key constraint...      1
# 71  1314902.0                     Remove duplicated vector icons      3
# 72  1401519.0   Top Sites area is still scrollable after reac...      3
# 73  1406046.0  Intermittent testActivityStreamPocketReferrer ...      1
# 74  1332621.0  Duplicate top sites due to multiple redirects ...      3
# 75  1400824.0                     Can't reorder the pinned sites      3
# 76  1390368.0  Intermittent testActivityStreamContextMenu | T...      1
# 77  1308582.0  Disabling installed Add-ons does not work prop...      1
# 78  1233548.0  Firefox for Android shows dialogs with "The ad...      3
# 79   841793.0  We should display add-ons that don't work on p...      1
# 80   887201.0  No obvious way to update extensions in Firefox...      3
# 81   895032.0  Do not initialize addon-manager related compon...      0
# 82   946617.0  Adding an add-on from our addons site doesn't ...      1
# 83  1010752.0  Add-ons Manager becomes horizontally scrollabl...      1
# 84  1049864.0  Investigate why the test for bug 687194 fails ...      1
# 85  1053402.0         UX work - Surface addons in browser chrome      1
# 86  1063245.0  Unable to copy or paste in add-on settings wit...      2
# 87  1108763.0  Lightweight themes are disabled in add-on mana...      1
# 88  1173896.0      No UI to explain disabled blocklisted add-ons      3
# 89  1194125.0  Show warning in add-on manager list for add-on...      1
# 90  1196203.0  Re-opening an add-on page from the history mig...      3
# 91  1197535.0  Installing the same extension multiple times w...      3
# 92  1202379.0  Firefox for Android should be clearer when fai...      3
# 93  1225969.0    Add a way to install addons from the Play Store      1
# 94  1230292.0  Improve failure message when installing via di...      1
# 95  1256717.0                    Possibly use the new disco pane      3
# 96  1348595.0  Intermittent dom/media/test/test_load.html | T...      1
# 97  1400818.0  Update icon overlaps the description text from...      1
# 98  1433670.0  Add-on install whitelist occasionally forgets ...      3
# 99  1091237.0  Show more information in add-ons detail view i...      1
#
# [100 rows x 3 columns]

# %%
resultdf.groupby(['label']).count()
# Out:
#        bugID  text
# label
# 0       1884  1982
# 1       2009  2063
# 2        103   107
# 3       1951  2002
